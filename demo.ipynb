# %%
from ipprl_tools import metrics
from ipprl_tools.utils.data import get_data
import pandas as pd

# %% [markdown]
# The `get_data` function will download a demo dataset CSV, which can be used to demostrate the metrics calculation.

# %%
demo_data_path = get_data()

# %% [markdown]
# **Note:** In order for metrics calculation to work correctly, it is important that we call the read_csv function with the following arguments:
#
# - `dtype=str` - Ensures that all columns are read in as strings (as opposed to numeric/date/etc). This is important as the metrics calculations assume they are working with strings.
# - `keep_default_na=False` - Ensures that missing values are coded as `''` instead of `np.nan` or some other value. The metric calculations will also assume that empty string `''` is the missing value placeholder.

# %%
demo_data = pd.read_csv(demo_data_path, dtype=str, keep_default_na=False)

# %% [markdown]
# We can now calculate metrics on the demo data, using the `run_metrics` function.

# %%
result_metrics = metrics.run_metrics(demo_data)

# %% [markdown]
# We can view the metrics within this notebook.

# %%
result_metrics
# Out:
#                    Mean Group Size  Median Group Size  Stdev Group Size  \
# row_id                    1.000000                1.0          0.000000
# address                   1.934928                1.0          1.282508
# cell_phone_number         1.063475                1.0          0.304271
# city                      8.341696                5.0         15.852526
# county                   68.862295               29.0        128.212054
# dob                       4.109908                4.0          2.835599
# father_first_name        63.709808               10.0        200.663789
# father_last_name          4.304776                1.0         19.389642
# first_name               34.077339                6.0         97.923743
# home_phone_number         1.902618                1.0          1.246427
# last_name                 5.269633                2.0         21.364072
# marital_status        42006.000000            33410.0      33707.226208
# middle_name              33.739759                6.0         97.777373
# mother_first_name        51.689089               13.0        123.176908
# mother_last_name          4.032576                1.0         18.751422
# race                  18002.571429             9153.0      24690.157581
# sex                   63009.000000            63009.0        283.000000
# ssn                       1.000016                1.0          0.003984
# state                  2470.941176             1650.0       2805.503271
# zip                       5.021638                4.0          3.876790
#
#                    Min Group Size  Max Group Size  Missing Data Ratio  \
# row_id                          1               1            0.000000
# address                         1              13            0.000000
# cell_phone_number               1               6            0.000603
# city                            1             666            0.000000
# county                          1            2424            0.000000
# dob                             1              32            0.000000
# father_first_name               1            3050            0.000000
# father_last_name                1            1208            0.000000
# first_name                      1            1813            0.000000
# home_phone_number               1              13            0.000000
# last_name                       1            1235            0.000000
# marital_status               5698           86910            0.000000
# middle_name                     1            1840            0.000000
# mother_first_name               1            1537            0.000000
# mother_last_name                1            1199            0.000000
# race                          204           76858            0.000000
# sex                         62726           63292            0.000000
# ssn                             1               2            0.000000
# state                         220           15026            0.000000
# zip                             1              36            0.000000
#
#                    Distinct Values Ratio  Shannon Entropy  \
# row_id                          1.000000        16.943270
# address                         0.516815        15.727277
# cell_phone_number               0.939755        16.809274
# city                            0.119880        12.979011
# county                          0.014522         9.674918
# dob                             0.243314        14.611513
# father_first_name               0.015696         8.681256
# father_last_name                0.232300        12.915957
# first_name                      0.029345         9.848584
# home_phone_number               0.525592        15.757274
# last_name                       0.189767        12.788687
# marital_status                  0.000024         1.079445
# middle_name                     0.029639         9.844487
# mother_first_name               0.019346         9.476584
# mother_last_name                0.247980        12.984405
# race                            0.000056         1.773664
# sex                             0.000016         0.999985
# ssn                             0.999984        16.943239
# state                           0.000405         5.002082
# zip                             0.199138        14.231454
#
#                    Theoretical Max Entropy  % Theoretical Max Entropy  \
# row_id                           16.943270                 100.000000
# address                          15.990990                  98.350864
# cell_phone_number                16.853626                  99.736840
# city                             13.882930                  93.488989
# county                           10.837628                  89.271546
# dob                              14.904164                  98.036445
# father_first_name                10.949827                  79.282129
# father_last_name                 14.837332                  87.050398
# first_name                       11.852530                  83.092674
# home_phone_number                16.015284                  98.388974
# last_name                        14.545568                  87.921536
# marital_status                    1.584963                  68.105367
# middle_name                      11.866893                  82.957580
# mother_first_name                11.251482                  84.225203
# mother_last_name                 14.931569                  86.959415
# race                              2.807355                  63.179176
# sex                               1.000000                  99.998545
# ssn                              16.943247                  99.999948
# state                             5.672425                  88.182421
# zip                              14.615112                  97.374924
#
#                    Row Count
# row_id                126018
# address               126018
# cell_phone_number     126018
# city                  126018
# county                126018
# dob                   126018
# father_first_name     126018
# father_last_name      126018
# first_name            126018
# home_phone_number     126018
# last_name             126018
# marital_status        126018
# middle_name           126018
# mother_first_name     126018
# mother_last_name      126018
# race                  126018
# sex                   126018
# ssn                   126018
# state                 126018
# zip                   126018

# %% [markdown]
# Finally, we write the computed metrics out to a file.

# %%
result_metrics.to_csv("demo_metrics_out.csv", index_label="data_column")
